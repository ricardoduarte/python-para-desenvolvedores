# %% [markdown]
# [Python para Desenvolvedores](http://ricardoduarte.github.io/python-para-desenvolvedores/#conteudo)
# ===================================
# 2&ordf; edição, revisada e ampliada
# -----------------------------------
#
# Capítulo 14: Introspecção
# =============================
# _____________________________
# Introspecção ou reflexão é capacidade do software de identificar e relatar suas próprias estruturas internas, tais como tipos, escopo de variáveis, métodos e atributos.
#
# Funções nativas do interpretador para introspecção:
#
# <table>
#     <tr>
#         <th>Função</th>
#         <th>Retorno</th>
#     </tr>
#     <tr>
#         <td><code>type(objeto)</code></td>
#         <td>O tipo (classe) do objeto</td>
#     </tr>
#     <tr>
#         <td><code>id(objeto)</code></td>
#         <td>O identificador do objeto</td>
#     </tr>
#     <tr>
#         <td><code>locals()</code></td>
#         <td>O dicionário de variáveis locais</td>
#     </tr>
#     <tr>
#         <td><code>globals()</code></td>
#         <td>O dicionário de variáveis globais</td>
#     </tr>
#     <tr>
#         <td><code>vars(objeto)</code></td>
#         <td>O dicionário de símbolos do objeto</td>
#     </tr>
#     <tr>
#         <td><code>len(objeto)</code></td>
#         <td>O tamanho do objeto</td>
#     </tr>
#     <tr>
#         <td><code>dir(objeto)</code></td>
#         <td>A lista de estruturas do objeto</td>
#     </tr>
#     <tr>
#         <td><code>help(objeto)</code></td>
#         <td>As Doc Strings do objeto</td>
#     </tr>
#     <tr>
#         <td><code>repr(objeto)</code></td>
#         <td>A representação do objeto</td>
#     </tr>
#     <tr>
#         <td><code>isinstance(objeto, classe)</code></td>
#         <td>Verdadeiro se objeto deriva da classe</td>
#     </tr>
#     <tr>
#         <td><code>issubclass(subclasse, classe)</code></td>
#         <td>Verdadeiro se subclasse herda classe</td>
#     </tr>
# </table>
#
# O identificador do objeto é um número inteiro único que é usado pelo interpretador para identificar internamente os objetos.
#
# Exemplo:

# %%
# Colhendo algumas informações
# dos objetos globais no programa

from types import ModuleType

def info(n_obj):

    # Cria uma referência ao objeto
    obj = globals()[n_obj]

    # Mostra informações sobre o objeto
    print 'Nome do objeto:', n_obj
    print 'Identificador:', id(obj)
    print 'Tipo:', type(obj)
    print 'Representação:', repr(obj)

    # Se for um módulo
    if isinstance(obj, ModuleType):
        print 'itens:'
        for item in dir(obj):
            print item
    print

# Mostrando as informações
for n_obj in dir():
    info(n_obj)
# Out:
# Nome do objeto: ALLOW_THREADS
# Identificador: 12876968
# Tipo: <type 'int'>
# Representação: 1
#
# Nome do objeto: Annotation
# Identificador: 33424432
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.text.Annotation'>
#
# Nome do objeto: Arrow
# Identificador: 30281072
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.patches.Arrow'>
#
# Nome do objeto: Artist
# Identificador: 29285488
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.artist.Artist'>
#
# Nome do objeto: AutoLocator
# Identificador: 30287696
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.ticker.AutoLocator'>
#
# Nome do objeto: Axes
# Identificador: 36438016
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.axes.Axes'>
#
# Nome do objeto: BUFSIZE
# Identificador: 18414272
# Tipo: <type 'int'>
# Representação: 8192
#
# Nome do objeto: Button
# Identificador: 31892672
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.widgets.Button'>
#
# Nome do objeto: CLIP
# Identificador: 12876992
# Tipo: <type 'int'>
# Representação: 0
#
# Nome do objeto: Circle
# Identificador: 30963200
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.patches.Circle'>
#
# Nome do objeto: ComplexWarning
# Identificador: 20430320
# Tipo: <type 'type'>
# Representação: <class 'numpy.core.numeric.ComplexWarning'>
#
# Nome do objeto: DAILY
# Identificador: 12876920
# Tipo: <type 'int'>
# Representação: 3
#
# Nome do objeto: DataSource
# Identificador: 22640368
# Tipo: <type 'type'>
# Representação: <class 'numpy.lib._datasource.DataSource'>
#
# Nome do objeto: DateFormatter
# Identificador: 35033248
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.dates.DateFormatter'>
#
# Nome do objeto: DateLocator
# Identificador: 35459424
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.dates.DateLocator'>
#
# Nome do objeto: DayLocator
# Identificador: 35467360
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.dates.DayLocator'>
#
# Nome do objeto: ERR_CALL
# Identificador: 12876920
# Tipo: <type 'int'>
# Representação: 3
#
# Nome do objeto: ERR_DEFAULT
# Identificador: 12876992
# Tipo: <type 'int'>
# Representação: 0
#
# Nome do objeto: ERR_DEFAULT2
# Identificador: 19485752
# Tipo: <type 'int'>
# Representação: 521
#
# Nome do objeto: ERR_IGNORE
# Identificador: 12876992
# Tipo: <type 'int'>
# Representação: 0
#
# Nome do objeto: ERR_LOG
# Identificador: 12876872
# Tipo: <type 'int'>
# Representação: 5
#
# Nome do objeto: ERR_PRINT
# Identificador: 12876896
# Tipo: <type 'int'>
# Representação: 4
#
# Nome do objeto: ERR_RAISE
# Identificador: 12876944
# Tipo: <type 'int'>
# Representação: 2
#
# Nome do objeto: ERR_WARN
# Identificador: 12876968
# Tipo: <type 'int'>
# Representação: 1
#
# Nome do objeto: FLOATING_POINT_SUPPORT
# Identificador: 12876968
# Tipo: <type 'int'>
# Representação: 1
#
# Nome do objeto: FPE_DIVIDEBYZERO
# Identificador: 12876968
# Tipo: <type 'int'>
# Representação: 1
#
# Nome do objeto: FPE_INVALID
# Identificador: 12876800
# Tipo: <type 'int'>
# Representação: 8
#
# Nome do objeto: FPE_OVERFLOW
# Identificador: 12876944
# Tipo: <type 'int'>
# Representação: 2
#
# Nome do objeto: FPE_UNDERFLOW
# Identificador: 12876896
# Tipo: <type 'int'>
# Representação: 4
#
# Nome do objeto: FR
# Identificador: 34859920
# Tipo: <class 'dateutil.rrule.weekday'>
# Representação: FR
#
# Nome do objeto: False_
# Identificador: 139890523409984
# Tipo: <type 'numpy.bool_'>
# Representação: False
#
# Nome do objeto: Figure
# Identificador: 36630944
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.figure.Figure'>
#
# Nome do objeto: FigureCanvasBase
# Identificador: 33136864
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.backend_bases.FigureCanvasBase'>
#
# Nome do objeto: FixedFormatter
# Identificador: 30311584
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.ticker.FixedFormatter'>
#
# Nome do objeto: FixedLocator
# Identificador: 30439152
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.ticker.FixedLocator'>
#
# Nome do objeto: FormatStrFormatter
# Identificador: 31324544
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.ticker.FormatStrFormatter'>
#
# Nome do objeto: Formatter
# Identificador: 30224720
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.ticker.Formatter'>
#
# Nome do objeto: FuncFormatter
# Identificador: 31322400
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.ticker.FuncFormatter'>
#
# Nome do objeto: GridSpec
# Identificador: 36386208
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.gridspec.GridSpec'>
#
# Nome do objeto: HOURLY
# Identificador: 12876896
# Tipo: <type 'int'>
# Representação: 4
#
# Nome do objeto: HourLocator
# Identificador: 35469072
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.dates.HourLocator'>
#
# Nome do objeto: In
# Identificador: 26302512
# Tipo: <type 'list'>
# Representação: ['', u"# Colhendo algumas informa\xe7\xf5es\n# dos objetos globais no programa\n\nfrom types import ModuleType\n\ndef info(n_obj):\n\n    # Cria uma refer\xeancia ao objeto\n    obj = globals()[n_obj]\n\n    # Mostra informa\xe7\xf5es sobre o objeto\n    print 'Nome do objeto:', n_obj\n    print 'Identificador:', id(obj)\n    print 'Tipo:', type(obj)\n    print 'Representa\xe7\xe3o:', repr(obj)\n\n    # Se for um m\xf3dulo\n    if isinstance(obj, ModuleType):\n        print 'itens:'\n        for item in dir(obj):\n            print item\n    print\n\n# Mostrando as informa\xe7\xf5es\nfor n_obj in dir():\n    info(n_obj)"]
#
# Nome do objeto: IndexDateFormatter
# Identificador: 35035360
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.dates.IndexDateFormatter'>
#
# Nome do objeto: IndexLocator
# Identificador: 30443440
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.ticker.IndexLocator'>
#
# Nome do objeto: Inf
# Identificador: 13692944
# Tipo: <type 'float'>
# Representação:
# inf
#
# Nome do objeto: Infinity
# Identificador: 13692944
# Tipo: <type 'float'>
# Representação: inf
#
# Nome do objeto: LinAlgError
# Identificador: 22258512
# Tipo: <type 'type'>
# Representação: <class 'numpy.linalg.linalg.LinAlgError'>
#
# Nome do objeto: Line2D
# Identificador: 30250960
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.lines.Line2D'>
#
# Nome do objeto: LinearLocator
# Identificador: 31264080
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.ticker.LinearLocator'>
#
# Nome do objeto: Locator
# Identificador: 30491776
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.ticker.Locator'>
#
# Nome do objeto: LogFormatter
# Identificador: 30039616
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.ticker.LogFormatter'>
#
# Nome do objeto: LogFormatterExponent
# Identificador: 30035328
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.ticker.LogFormatterExponent'>
#
# Nome do objeto: LogFormatterMathtext
# Identificador: 30980736
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.ticker.LogFormatterMathtext'>
#
# Nome do objeto: LogLocator
# Identificador: 30633056
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.ticker.LogLocator'>
#
# Nome do objeto: MAXDIMS
# Identificador: 12876224
# Tipo: <type 'int'>
# Representação: 32
#
# Nome do objeto: MINUTELY
# Identificador: 12876872
# Tipo: <type 'int'>
# Representação: 5
#
# Nome do objeto: MO
# Identificador: 34859664
# Tipo: <class 'dateutil.rrule.weekday'>
# Representação: MO
#
# Nome do objeto: MONTHLY
# Identificador: 12876968
# Tipo: <type 'int'>
# Representação: 1
#
# Nome do objeto: MachAr
# Identificador: 21110048
# Tipo: <type 'type'>
# Representação: <class 'numpy.core.machar.MachAr'>
#
# Nome do objeto: MaxNLocator
# Identificador: 31330976
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.ticker.MaxNLocator'>
#
# Nome do objeto: MinuteLocator
# Identificador: 35470784
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.dates.MinuteLocator'>
#
# Nome do objeto: ModuleType
# Identificador: 8686656
# Tipo: <type 'type'>
# Representação: <type 'module'>
#
# Nome do objeto: MonthLocator
# Identificador: 35464512
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.dates.MonthLocator'>
#
# Nome do objeto: MultipleLocator
# Identificador: 30278928
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.ticker.MultipleLocator'>
#
# Nome do objeto: NAN
# Identificador: 13692848
# Tipo: <type 'float'>
# Representação: nan
#
# Nome do objeto: NINF
# Identificador: 13692920
# Tipo: <type 'float'>
# Representação: -inf
#
# Nome do objeto: NZERO
# Identificador: 13692872
# Tipo: <type 'float'>
# Representação: -0.0
#
# Nome do objeto: NaN
# Identificador: 13692848
# Tipo: <type 'float'>
# Representação: nan
#
# Nome do objeto: Normalize
# Identificador: 28708336
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.colors.Normalize'>
#
# Nome do objeto: NullFormatter
# Identificador: 30324448
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.ticker.NullFormatter'>
#
# Nome do objeto: NullLocator
# Identificador: 30296272
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.ticker.NullLocator'>
#
# Nome do objeto: Out
# Identificador: 26584464
# Tipo: <type 'dict'>
# Representação: {}
#
# Nome do objeto: PINF
# Identificador: 13692944
# Tipo: <type 'float'>
# Representação: inf
#
# Nome do objeto: PZERO
# Identificador: 13692896
# Tipo: <type 'float'>
# Representação: 0.0
#
# Nome do objeto: PackageLoader
# Identificador: 19544224
# Tipo: <type 'type'>
# Representação: <class 'numpy._import_tools.PackageLoader'>
#
# Nome do objeto: PolarAxes
# Identificador: 36716000
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.projections.polar.PolarAxes'>
#
# Nome do objeto: Polygon
# Identificador: 30639488
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.patches.Polygon'>
#
# Nome do objeto: RAISE
# Identificador: 12876944
# Tipo: <type 'int'>
# Representação: 2
#
# Nome do objeto: RRuleLocator
# Identificador: 35460384
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.dates.RRuleLocator'>
#
# Nome do objeto: RankWarning
# Identificador: 22264240
# Tipo: <type 'type'>
# Representação: <class 'numpy.lib.polynomial.RankWarning'>
#
# Nome do objeto: Rectangle
# Identificador: 30652352
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.patches.Rectangle'>
#
# Nome do objeto: SA
# Identificador: 34859984
# Tipo: <class 'dateutil.rrule.weekday'>
# Representação: SA
#
# Nome do objeto: SECONDLY
# Identificador: 12876848
# Tipo: <type 'int'>
# Representação: 6
#
# Nome do objeto: SHIFT_DIVIDEBYZERO
# Identificador: 12876992
# Tipo: <type 'int'>
# Representação: 0
#
# Nome do objeto: SHIFT_INVALID
# Identificador: 12876776
# Tipo: <type 'int'>
# Representação: 9
#
# Nome do objeto: SHIFT_OVERFLOW
# Identificador: 12876920
# Tipo: <type 'int'>
# Representação: 3
#
# Nome do objeto: SHIFT_UNDERFLOW
# Identificador: 12876848
# Tipo: <type 'int'>
# Representação: 6
#
# Nome do objeto: SU
# Identificador: 34860048
# Tipo: <class 'dateutil.rrule.weekday'>
# Representação: SU
#
# Nome do objeto: ScalarFormatter
# Identificador: 30513552
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.ticker.ScalarFormatter'>
#
# Nome do objeto: ScalarType
# Identificador: 20397008
# Tipo: <type 'tuple'>
# Representação: (<type 'int'>, <type 'float'>, <type 'complex'>, <type 'long'>, <type 'bool'>, <type 'str'>, <type 'unicode'>, <type 'buffer'>, <type 'numpy.float16'>, <type 'numpy.string_'>, <type 'numpy.float128'>, <type 'numpy.uint64'>, <type 'numpy.int16'>, <type 'numpy.timedelta64'>, <type 'numpy.object_'>, <type 'numpy.float64'>, <type 'numpy.int64'>, <type 'numpy.uint8'>, <type 'numpy.datetime64'>, <type 'numpy.complex256'>, <type 'numpy.float32'>, <type 'numpy.uint32'>, <type 'numpy.int8'>, <type 'numpy.void'>, <type 'numpy.complex128'>, <type 'numpy.uint64'>, <type 'numpy.int32'>, <type 'numpy.bool_'>, <type 'numpy.unicode_'>, <type 'numpy.complex64'>, <type 'numpy.int64'>, <type 'numpy.uint16'>)
#
# Nome do objeto: SecondLocator
# Identificador: 35472496
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.dates.SecondLocator'>
#
# Nome do objeto: Slider
# Identificador: 31878352
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.widgets.Slider'>
#
# Nome do objeto: Subplot
# Identificador: 36553744
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.axes.AxesSubplot'>
#
# Nome do objeto: SubplotTool
# Identificador: 31885888
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.widgets.SubplotTool'>
#
# Nome do objeto: TH
# Identificador: 34859856
# Tipo: <class 'dateutil.rrule.weekday'>
# Representação: TH
#
# Nome do objeto: TU
# Identificador: 34859728
# Tipo: <class 'dateutil.rrule.weekday'>
# Representação: TU
#
# Nome do objeto: Tester
# Identificador: 21652496
# Tipo: <type 'type'>
# Representação: <class 'numpy.testing.nosetester.NoseTester'>
#
# Nome do objeto: Text
# Identificador: 30522128
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.text.Text'>
#
# Nome do objeto: TickHelper
# Identificador: 31285664
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.ticker.TickHelper'>
#
# Nome do objeto: True_
# Identificador: 139890523410008
# Tipo: <type 'numpy.bool_'>
# Representação: True
#
# Nome do objeto: UFUNC_BUFSIZE_DEFAULT
# Identificador: 19485728
# Tipo: <type 'int'>
# Representação: 8192
#
# Nome do objeto: UFUNC_PYVALS_NAME
# Identificador: 19373000
# Tipo: <type 'str'>
# Representação: 'UFUNC_PYVALS'
#
# Nome do objeto: WE
# Identificador: 34859792
# Tipo: <class 'dateutil.rrule.weekday'>
# Representação: WE
#
# Nome do objeto: WEEKLY
# Identificador: 12876944
# Tipo: <type 'int'>
# Representação: 2
#
# Nome do objeto: WRAP
# Identificador: 12876968
# Tipo: <type 'int'>
# Representação: 1
#
# Nome do objeto: WeekdayLocator
# Identificador: 35465936
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.dates.WeekdayLocator'>
#
# Nome do objeto: Widget
# Identificador: 31899584
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.widgets.Widget'>
#
# Nome do objeto: YEARLY
# Identificador: 12876992
# Tipo: <type 'int'>
# Representação: 0
#
# Nome do objeto: YearLocator
# Identificador: 35463088
# Tipo: <type 'type'>
# Representação: <class 'matplotlib.dates.YearLocator'>
#
# Nome do objeto: _
# Identificador: 139890631345416
# Tipo: <type 'str'>
# Representação: ''
#
# Nome do objeto: __
# Identificador: 139890631345416
# Tipo: <type 'str'>
# Representação: ''
#
# Nome do objeto: ___
# Identificador: 139890631345416
# Tipo: <type 'str'>
# Representação: ''
#
# Nome do objeto: __builtin__
# Identificador: 139890631326472
# Tipo: <type 'module'>
# Representação: <module '__builtin__' (built-in)>
# itens:
# ArithmeticError
# AssertionError
# AttributeError
# BaseException
# BufferError
# BytesWarning
# DeprecationWarning
# EOFError
# Ellipsis
# EnvironmentError
# Exception
# False
# FloatingPointError
# FutureWarning
# GeneratorExit
# IOError
# ImportError
# ImportWarning
# IndentationError
# IndexError
# KeyError
# KeyboardInterrupt
# LookupError
# MemoryError
# NameError
# None
# NotImplemented
# NotImplementedError
# OSError
# OverflowError
# PendingDeprecationWarning
# ReferenceError
# RuntimeError
# RuntimeWarning
# StandardError
# StopIteration
# SyntaxError
# SyntaxWarning
# SystemError
# SystemExit
# TabError
# True
# TypeError
# UnboundLocalError
# UnicodeDecodeError
# UnicodeEncodeError
# UnicodeError
# UnicodeTranslateError
# UnicodeWarning
# UserWarning
# ValueError
# Warning
# ZeroDivisionError
# __IPYTHON__
# __IPYTHON__active
# __debug__
# __doc__
# __import__
# __name__
# __package__
# abs
# all
# any
# apply
# basestring
# bin
# bool
# buffer
# bytearray
# bytes
# callable
# chr
# classmethod
# cmp
# coerce
# compile
# complex
# copyright
# credits
# delattr
# dict
# dir
# divmod
# dreload
# enumerate
# eval
# execfile
# file
# filter
# float
# format
# frozenset
# get_ipython
# getattr
# globals
# hasattr
# hash
# help
# hex
# id
# input
# int
# intern
# isinstance
# issubclass
# iter
# len
# license
# list
# locals
# long
# map
# max
# memoryview
# min
# next
# object
# oct
# open
# ord
# pow
# print
# property
# range
# raw_input
# reduce
# reload
# repr
# reversed
# round
# set
# setattr
# slice
# sorted
# staticmethod
# str
# sum
# super
# tuple
# type
# unichr
# unicode
# vars
# xrange
# zip
#
# Nome do objeto: __builtins__
# Identificador: 12892128
# Tipo: <type 'dict'>
# Representação:
# {'bytearray': <type 'bytearray'>, 'IndexError': <type 'exceptions.IndexError'>, 'all': <built-in function all>, 'help': Type help() for interactive help, or help(object) for help about object., 'vars': <built-in function vars>, 'SyntaxError': <type 'exceptions.SyntaxError'>, '__IPYTHON__active': 'Deprecated, check for __IPYTHON__', 'unicode': <type 'unicode'>, 'UnicodeDecodeError': <type 'exceptions.UnicodeDecodeError'>, 'memoryview': <type 'memoryview'>, 'isinstance': <built-in function isinstance>, 'copyright': Copyright (c) 2001-2013 Python Software Foundation.
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved., 'NameError': <type 'exceptions.NameError'>, 'BytesWarning': <type 'exceptions.BytesWarning'>, 'dict': <type 'dict'>, 'input': <built-in function input>, 'oct': <built-in function oct>, 'bin': <built-in function bin>, 'SystemExit': <type 'exceptions.SystemExit'>, 'StandardError': <type 'exceptions.StandardError'>, 'format': <built-in function format>, 'repr': <built-in function repr>, 'sorted': <built-in function sorted>, 'False': False, 'RuntimeWarning': <type 'exceptions.RuntimeWarning'>, 'list': <type 'list'>, 'iter': <built-in function iter>, 'reload': <built-in function reload>, 'Warning': <type 'exceptions.Warning'>, '__package__': None, 'round': <built-in function round>, 'dir': <built-in function dir>, 'cmp': <built-in function cmp>, 'set': <type 'set'>, 'bytes': <type 'str'>, 'reduce': <built-in function reduce>, 'intern': <built-in function intern>, 'issubclass': <built-in function issubclass>, 'Ellipsis': Ellipsis, 'EOFError': <type 'exceptions.EOFError'>, 'locals': <built-in function locals>, 'BufferError': <type 'exceptions.BufferError'>, 'slice': <type 'slice'>, 'FloatingPointError': <type 'exceptions.FloatingPointError'>, 'sum': <built-in function sum>, 'getattr': <built-in function getattr>, 'abs': <built-in function abs>, 'print': <built-in function print>, 'True': True, 'FutureWarning': <type 'exceptions.FutureWarning'>, 'ImportWarning': <type 'exceptions.ImportWarning'>, 'None': None, 'hash': <built-in function hash>, 'ReferenceError': <type 'exceptions.ReferenceError'>, 'len': <built-in function len>, 'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#     for supporting Python development.  See www.python.org for more information., 'frozenset': <type 'frozenset'>, '__name__': '__builtin__', 'ord': <built-in function ord>, 'super': <type 'super'>, 'TypeError': <type 'exceptions.TypeError'>, 'license': Type license() to see the full license text, 'KeyboardInterrupt': <type 'exceptions.KeyboardInterrupt'>, 'UserWarning': <type 'exceptions.UserWarning'>, 'filter': <built-in function filter>, 'range': <built-in function range>, 'staticmethod': <type 'staticmethod'>, 'SystemError': <type 'exceptions.SystemError'>, 'BaseException': <type 'exceptions.BaseException'>, 'pow': <built-in function pow>, 'RuntimeError': <type 'exceptions.RuntimeError'>, 'float': <type 'float'>, 'MemoryError': <type 'exceptions.MemoryError'>, 'StopIteration': <type 'exceptions.StopIteration'>, 'globals': <built-in function globals>, 'divmod': <built-in function divmod>, 'enumerate': <type 'enumerate'>, 'apply': <built-in function apply>, 'LookupError': <type 'exceptions.LookupError'>, 'open': <built-in function open>, 'basestring': <type 'basestring'>, 'UnicodeError': <type 'exceptions.UnicodeError'>, 'zip': <built-in function zip>, 'hex': <built-in function hex>, 'long': <type 'long'>, 'next': <built-in function next>, 'ImportError': <type 'exceptions.ImportError'>, 'chr': <built-in function chr>, 'xrange': <type 'xrange'>, 'type': <type 'type'>, '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.", 'Exception': <type 'exceptions.Exception'>, '__IPYTHON__': True, 'tuple': <type 'tuple'>, 'UnicodeTranslateError': <type 'exceptions.UnicodeTranslateError'>, 'reversed': <type 'reversed'>, 'UnicodeEncodeError': <type 'exceptions.UnicodeEncodeError'>, 'IOError': <type 'exceptions.IOError'>, 'hasattr': <built-in function hasattr>, 'delattr': <built-in function delattr>, 'setattr': <built-in function setattr>, 'raw_input': <function <lambda> at 0x242db18>, 'SyntaxWarning': <type 'exceptions.SyntaxWarning'>, 'compile': <built-in function compile>, 'ArithmeticError': <type 'exceptions.ArithmeticError'>, 'str': <type 'str'>, 'property': <type 'property'>, 'dreload': <function reload at 0x190f500>, 'GeneratorExit': <type 'exceptions.GeneratorExit'>, 'int': <type 'int'>, '__import__': <built-in function __import__>, 'KeyError': <type 'exceptions.KeyError'>, 'coerce': <built-in function coerce>, 'PendingDeprecationWarning': <type 'exceptions.PendingDeprecationWarning'>, 'file': <type 'file'>, 'EnvironmentError': <type 'exceptions.EnvironmentError'>, 'unichr': <built-in function unichr>, 'id': <built-in function id>, 'OSError': <type 'exceptions.OSError'>, 'DeprecationWarning': <type 'exceptions.DeprecationWarning'>, 'min': <built-in function min>, 'UnicodeWarning': <type 'exceptions.UnicodeWarning'>, 'execfile': <built-in function execfile>, 'any': <built-in function any>, 'complex': <type 'complex'>, 'bool': <type 'bool'>, 'get_ipython': <bound method ZMQInteractiveShell.get_ipython of <IPython.zmq.zmqshell.ZMQInteractiveShell object at 0x1910390>>, 'ValueError': <type 'exceptions.ValueError'>, 'NotImplemented': NotImplemented, 'map': <built-in function map>, 'buffer': <type 'buffer'>, 'max': <built-in function max>, 'object': <type 'object'>, 'TabError': <type 'exceptions.TabError'>, 'callable': <built-in function callable>, 'ZeroDivisionError': <type 'exceptions.ZeroDivisionError'>, 'eval': <built-in function eval>, '__debug__': True, 'IndentationError': <type 'exceptions.IndentationError'>, 'AssertionError': <type 'exceptions.AssertionError'>, 'classmethod': <type 'classmethod'>, 'UnboundLocalError': <type 'exceptions.UnboundLocalError'>, 'NotImplementedError': <type 'exceptions.NotImplementedError'>, 'AttributeError': <type 'exceptions.AttributeError'>, 'OverflowError': <type 'exceptions.OverflowError'>}
#
# Nome do objeto: __name__
# Identificador: 139890631063280
# Tipo: <type 'str'>
# Representação: '__main__'
#
# Nome do objeto: __package__
# Identificador: 8696288
# Tipo: <type 'NoneType'>
# Representação: None
#
# Nome do objeto: __version__
# Identificador: 19274272
# Tipo: <type 'str'>
# Representação: '1.7.1'
#
# Nome do objeto: _dh
# Identificador: 26304312
# Tipo: <type 'list'>
# Representação: [u'/home/lslf/projetos/github/python-para-desenvolvedores/Capitulo14']
#
# Nome do objeto: _i
# Identificador: 139890631500160
# Tipo: <type 'unicode'>
# Representação: u''
#
# Nome do objeto: _i1
# Identificador: 37947456
# Tipo: <type 'unicode'>
# Representação: u"# Colhendo algumas informa\xe7\xf5es\n# dos objetos globais no programa\n\nfrom types import ModuleType\n\ndef info(n_obj):\n\n    # Cria uma refer\xeancia ao objeto\n    obj = globals()[n_obj]\n\n    # Mostra informa\xe7\xf5es sobre o objeto\n    print 'Nome do objeto:', n_obj\n    print 'Identificador:', id(obj)\n    print 'Tipo:', type(obj)\n    print 'Representa\xe7\xe3o:', repr(obj)\n\n    # Se for um m\xf3dulo\n    if isinstance(obj, ModuleType):\n        print 'itens:'\n        for item in dir(obj):\n            print item\n    print\n\n# Mostrando as informa\xe7\xf5es\nfor n_obj in dir():\n    info(n_obj)"
#
# Nome do objeto: _ih
# Identificador: 26302512
# Tipo: <type 'list'>
# Representação: ['', u"# Colhendo algumas informa\xe7\xf5es\n# dos objetos globais no programa\n\nfrom types import ModuleType\n\ndef info(n_obj):\n\n    # Cria uma refer\xeancia ao objeto\n    obj = globals()[n_obj]\n\n    # Mostra informa\xe7\xf5es sobre o objeto\n    print 'Nome do objeto:', n_obj\n    print 'Identificador:', id(obj)\n    print 'Tipo:', type(obj)\n    print 'Representa\xe7\xe3o:', repr(obj)\n\n    # Se for um m\xf3dulo\n    if isinstance(obj, ModuleType):\n        print 'itens:'\n        for item in dir(obj):\n            print item\n    print\n\n# Mostrando as informa\xe7\xf5es\nfor n_obj in dir():\n    info(n_obj)"]
#
# Nome do objeto: _ii
# Identificador: 139890631500160
# Tipo: <type 'unicode'>
# Representação: u''
#
# Nome do objeto: _iii
# Identificador: 139890631500160
# Tipo: <type 'unicode'>
# Representação: u''
#
# Nome do objeto: _oh
# Identificador: 26584464
# Tipo: <type 'dict'>
# Representação: {}
#
# Nome do objeto: _sh
# Identificador: 139890588034224
# Tipo: <type 'module'>
# Representação: <module 'IPython.core.shadowns' from '/usr/local/lib/python2.7/dist-packages/IPython/core/shadowns.pyc'>
# itens:
# __builtins__
# __doc__
# __file__
# __name__
# __package__
#
# Nome do objeto: absolute
# Identificador: 16871744
# Tipo: <type 'numpy.ufunc'>
# Representação: <ufunc 'absolute'>
#
# Nome do objeto: acorr
# Identificador: 36947680
# Tipo: <type 'function'>
# Representação: <function acorr at 0x233c6e0>
#
# Nome do objeto: add
# Identificador: 17613936
# Tipo: <type 'numpy.ufunc'>
# Representação: <ufunc 'add'>
#
# Nome do objeto: add_docstring
# Identificador: 21779952
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in function add_docstring>
#
# Nome do objeto: add_newdoc
# Identificador: 21864032
# Tipo: <type 'function'>
# Representação: <function add_newdoc at 0x14d9e60>
#
# Nome do objeto: add_newdoc_ufunc
# Identificador: 21780024
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in function add_newdoc_ufunc>
#
# Nome do objeto: add_newdocs
# Identificador: 19298968
# Tipo: <type 'module'>
# Representação: <module 'numpy.add_newdocs' from '/usr/lib/python2.7/dist-packages/numpy/add_newdocs.pyc'>
# itens:
# __builtins__
# __doc__
# __file__
# __name__
# __package__
# add_newdoc
#
# Nome do objeto: alen
# Identificador: 20732936
# Tipo: <type 'function'>
# Representação: <function alen at 0x13c5c08>
#
# Nome do objeto: all
# Identificador: 20732216
# Tipo: <type 'function'>
# Representação: <function all at 0x13c5938>
#
# Nome do objeto: allclose
# Identificador: 20739208
# Tipo: <type 'function'>
# Representação: <function allclose at 0x13c7488>
#
# Nome do objeto: alltrue
# Identificador: 20731976
# Tipo: <type 'function'>
# Representação: <function alltrue at 0x13c5848>
#
# Nome do objeto: alterdot
# Identificador: 20024856
# Tipo: <type 'builtin_function_or_method'>
# Representação:
# <built-in function alterdot>
#
# Nome do objeto: amap
# Identificador: 32390152
# Tipo: <type 'function'>
# Representação: <function amap at 0x1ee3c08>
#
# Nome do objeto: amax
# Identificador: 20732696
# Tipo: <type 'function'>
# Representação: <function amax at 0x13c5b18>
#
# Nome do objeto: amin
# Identificador: 20732816
# Tipo: <type 'function'>
# Representação: <function amin at 0x13c5b90>
#
# Nome do objeto: angle
# Identificador: 21855480
# Tipo: <type 'function'>
# Representação: <function angle at 0x14d7cf8>
#
# Nome do objeto: annotate
# Identificador: 36954312
# Tipo: <type 'function'>
# Representação: <function annotate at 0x233e0c8>
#
# Nome do objeto: any
# Identificador: 20732096
# Tipo: <type 'function'>
# Representação: <function any at 0x13c58c0>
#
# Nome do objeto: append
# Identificador: 21864648
# Tipo: <type 'function'>
# Representação: <function append at 0x14da0c8>
#
# Nome do objeto: apply_along_axis
# Identificador: 21901632
# Tipo: <type 'function'>
# Representação: <function apply_along_axis at 0x14e3140>
#
# Nome do objeto: apply_over_axes
# Identificador: 21901752
# Tipo: <type 'function'>
# Representação: <function apply_over_axes at 0x14e31b8>
#
# Nome do objeto: arange
# Identificador: 19351528
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in function arange>
#
# Nome do objeto: arccos
# Identificador: 17632816
# Tipo: <type 'numpy.ufunc'>
# Representação: <ufunc 'arccos'>
#
# Nome do objeto: arccosh
# Identificador: 17633584
# Tipo: <type 'numpy.ufunc'>
# Representação: <ufunc 'arccosh'>
#
# Nome do objeto: arcsin
# Identificador: 17969296
# Tipo: <type 'numpy.ufunc'>
# Representação: <ufunc 'arcsin'>
#
# Nome do objeto: arcsinh
# Identificador: 18082592
# Tipo: <type 'numpy.ufunc'>
# Representação: <ufunc 'arcsinh'>
#
# Nome do objeto: arctan
# Identificador: 18154160
# Tipo: <type 'numpy.ufunc'>
# Representação: <ufunc 'arctan'>
#
# Nome do objeto: arctan2
# Identificador: 16053680
# Tipo: <type 'numpy.ufunc'>
# Representação: <ufunc 'arctan2'>
#
# Nome do objeto: arctanh
# Identificador: 18516224
# Tipo: <type 'numpy.ufunc'>
# Representação: <ufunc 'arctanh'>
#
# Nome do objeto: argmax
# Identificador: 20730176
# Tipo: <type 'function'>
# Representação: <function argmax at 0x13c5140>
#
# Nome do objeto: argmin
# Identificador: 20730296
# Tipo: <type 'function'>
# Representação: <function argmin at 0x13c51b8>
#
# Nome do objeto: argsort
# Identificador: 20730056
# Tipo: <type 'function'>
# Representação: <function argsort at 0x13c50c8>
#
# Nome do objeto: argwhere
# Identificador: 20110824
# Tipo: <type 'function'>
# Representação: <function argwhere at 0x132dde8>
#
# Nome do objeto: around
# Identificador: 20733656
# Tipo: <type 'function'>
# Representação: <function around at 0x13c5ed8>
#
# Nome do objeto: array
# Identificador: 19351312
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in function array>
#
# Nome do objeto: array2string
# Identificador: 20735472
# Tipo: <type 'function'>
# Representação: <function array2string at 0x13c65f0>
#
# Nome do objeto: array_equal
# Identificador: 20739448
# Tipo: <type 'function'>
# Representação: <function array_equal at 0x13c7578>
#
# Nome do objeto: array_equiv
# Identificador: 20739568
# Tipo: <type 'function'>
# Representação: <function array_equiv at 0x13c75f0>
#
# Nome do objeto: array_repr
# Identificador: 20736312
# Tipo: <type 'function'>
# Representação: <function array_repr at 0x13c6938>
#
# Nome do objeto: array_split
# Identificador: 21902352
# Tipo: <type 'function'>
# Representação: <function array_split at 0x14e3410>
#
# Nome do objeto: array_str
# Identificador: 20737872
# Tipo: <type 'function'>
# Representação: <function array_str at 0x13c6f50>
#
# Nome do objeto: arrow
# Identificador: 36947800
# Tipo: <type 'function'>
# Representação: <function arrow at 0x233c758>
#
# Nome do objeto: asanyarray
# Identificador: 20110224
# Tipo: <type 'function'>
# Representação: <function asanyarray at 0x132db90>
#
# Nome do objeto: asarray
# Identificador: 20110104
# Tipo: <type 'function'>
# Representação: <function asarray at 0x132db18>
#
# Nome do objeto: asarray_chkfinite
# Identificador: 21854640
# Tipo: <type 'function'>
# Representação: <function asarray_chkfinite at 0x14d79b0>
#
# Nome do objeto: ascontiguousarray
# Identificador: 20110344
# Tipo: <type 'function'>
# Representação: <function ascontiguousarray at 0x132dc08>
#
# Nome do objeto: asfarray
# Identificador: 21502984
# Tipo: <type 'function'>
# Representação: <function asfarray at 0x1481c08>
#
# Nome do objeto: asfortranarray
# Identificador: 20110464
# Tipo: <type 'function'>
# Representação: <function asfortranarray at 0x132dc80>
#
# Nome do objeto: asmatrix
# Identificador: 21865248
# Tipo: <type 'function'>
# Representação: <function asmatrix at 0x14da320>
#
# Nome do objeto: asscalar
# Identificador: 21508416
# Tipo: <type 'function'>
# Representação: <function asscalar at 0x1483140>
#
# Nome do objeto: atleast_1d
# Identificador: 20854616
# Tipo: <type 'function'>
# Representação: <function atleast_1d at 0x13e3758>
#
# Nome do objeto: atleast_2d
# Identificador: 20855816
# Tipo: <type 'function'>
# Representação: <function atleast_2d at 0x13e3c08>
#
# Nome do objeto: atleast_3d
# Identificador: 20855936
# Tipo: <type 'function'>
# Representação: <function atleast_3d at 0x13e3c80>
#
# Nome do objeto: autoscale
# Identificador: 36954912
# Tipo: <type 'function'>
# Representação: <function autoscale at 0x233e320>
#
# Nome do objeto: autumn
# Identificador: 36947440
# Tipo: <type 'function'>
# Representação: <function autumn at 0x233c5f0>
#
# Nome do objeto: average
# Identificador: 21854520
# Tipo: <type 'function'>
# Representação: <function average at 0x14d7938>
#
# Nome do objeto: axes
# Identificador: 36942384
# Tipo: <type 'function'>
# Representação: <function axes at 0x233b230>
#
# Nome do objeto: axhline
# Identificador: 36947920
# Tipo: <type 'function'>
# Representação: <function axhline at 0x233c7d0>
#
# Nome do objeto: axhspan
# Identificador: 36948040
# Tipo: <type 'function'>
# Representação: <function axhspan at 0x233c848>
#
# Nome do objeto: axis
# Identificador: 36944064
# Tipo: <type 'function'>
# Representação: <function axis at 0x233b8c0>
#
# Nome do objeto: axvline
# Identificador: 36948160
# Tipo: <type 'function'>
# Representação: <function axvline at 0x233c8c0>
#
# Nome do objeto: axvspan
# Identificador: 36948280
# Tipo: <type 'function'>
# Representação: <function axvspan at 0x233c938>
#
# Nome do objeto: bar
# Identificador: 36948400
# Tipo: <type 'function'>
# Representação: <function bar at 0x233c9b0>
#
# Nome do objeto: barbs
# Identificador: 36953456
# Tipo: <type 'function'>
# Representação: <function barbs at 0x233dd70>
#
# Nome do objeto: barh
# Identificador: 36948520
# Tipo: <type 'function'>
# Representação: <function barh at 0x233ca28>
#
# Nome do objeto: bartlett
# Identificador: 21862352
# Tipo: <type 'function'>
# Representação: <function bartlett at 0x14d97d0>
#
# Nome do objeto: base_repr
# Identificador: 20738728
# Tipo: <type 'function'>
# Representação: <function base_repr at 0x13c72a8>
#
# Nome do objeto: bench
# Identificador: 139890578367264
# Tipo: <type 'instancemethod'>
# Representação: <bound method NoseTester.test of <numpy.testing.nosetester.NoseTester object at 0x1552410>>
#
# Nome do objeto: beta
# Identificador: 23953560
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in method beta of mtrand.RandomState object at 0x7f3ad35f43d8>
#
# Nome do objeto: binary_repr
# Identificador: 20738608
# Tipo: <type 'function'>
# Representação: <function binary_repr at 0x13c7230>
#
# Nome do objeto: bincount
# Identificador: 20897520
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in function bincount>
#
# Nome do objeto: binomial
# Identificador: 23955144
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in method binomial of mtrand.RandomState object at 0x7f3ad35f43d8>
#
# Nome do objeto: bitwise_and
# Identificador: 18306256
# Tipo: <type 'numpy.ufunc'>
# Representação: <ufunc 'bitwise_and'>
#
# Nome do objeto: bitwise_not
# Identificador: 18051600
# Tipo: <type 'numpy.ufunc'>
# Representação: <ufunc 'invert'>
#
# Nome do objeto: bitwise_or
# Identificador: 18685472
# Tipo: <type 'numpy.ufunc'>
# Representação: <ufunc 'bitwise_or'>
#
# Nome do objeto: bitwise_xor
# Identificador: 19464112
# Tipo: <type 'numpy.ufunc'>
# Representação: <ufunc 'bitwise_xor'>
#
# Nome do objeto: bivariate_normal
# Identificador: 32387992
# Tipo: <type 'function'>
# Representação: <function bivariate_normal at 0x1ee3398>
#
# Nome do objeto: blackman
# Identificador: 21862232
# Tipo: <type 'function'>
# Representação: <function blackman at 0x14d9758>
#
# Nome do objeto: bmat
# Identificador: 21898136
# Tipo: <type 'function'>
# Representação: <function bmat at 0x14e2398>
#
# Nome do objeto: bone
# Identificador: 36955032
# Tipo: <type 'function'>
# Representação: <function bone at 0x233e398>
#
# Nome do objeto: bool8
# Identificador: 139890523407904
# Tipo: <type 'type'>
# Representação: <type 'numpy.bool_'>
#
# Nome do objeto: bool_
# Identificador: 139890523407904
# Tipo: <type 'type'>
# Representação: <type 'numpy.bool_'>
#
# Nome do objeto: box
# Identificador: 36943824
# Tipo: <type 'function'>
# Representação: <function box at 0x233b7d0>
#
# Nome do objeto: boxplot
# Identificador: 36948760
# Tipo: <type 'function'>
# Representação: <function boxplot at 0x233cb18>
#
# Nome do objeto: broadcast
# Identificador: 139890523409568
# Tipo: <type 'type'>
# Representação: <type 'numpy.broadcast'>
#
# Nome do objeto: broadcast_arrays
# Identificador: 21903912
# Tipo: <type 'function'>
# Representação: <function broadcast_arrays at 0x14e3a28>
#
# Nome do objeto: broken_barh
# Identificador: 36948640
# Tipo: <type 'function'>
# Representação: <function broken_barh at 0x233caa0>
#
# Nome do objeto: busday_count
# Identificador: 19353472
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in function busday_count>
#
# Nome do objeto: busday_offset
# Identificador: 19353400
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in function busday_offset>
#
# Nome do objeto: busdaycalendar
# Identificador: 139890523418176
# Tipo: <type 'type'>
# Representação: <type 'numpy.busdaycalendar'>
#
# Nome do objeto: byte
# Identificador: 139890523407488
# Tipo: <type 'type'>
# Representação: <type 'numpy.int8'>
#
# Nome do objeto: byte_bounds
# Identificador: 21805728
# Tipo: <type 'function'>
# Representação: <function byte_bounds at 0x14cbaa0>
#
# Nome do objeto: bytes
# Identificador: 8694144
# Tipo: <type 'type'>
# Representação: <type 'str'>
#
# Nome do objeto: bytes_
# Identificador: 139890523400416
# Tipo: <type 'type'>
# Representação: <type 'numpy.string_'>
#
# Nome do objeto: c_
# Identificador: 21885776
# Tipo: <class 'numpy.lib.index_tricks.CClass'>
# Representação: <numpy.lib.index_tricks.CClass object at 0x14df350>
#
# Nome do objeto: can_cast
# Identificador: 19352968
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in function can_cast>
#
# Nome do objeto: cast
# Identificador: 20396352
# Tipo: <class 'numpy.core.numerictypes._typedict'>
# Representação: {<type 'numpy.float16'>: <function <lambda> at 0x132b7d0>, <type 'numpy.string_'>: <function <lambda> at 0x132b848>, <type 'numpy.float128'>: <function <lambda> at 0x132b8c0>, <type 'numpy.uint64'>: <function <lambda> at 0x132b938>, <type 'numpy.int16'>: <function <lambda> at 0x132b9b0>, <type 'numpy.timedelta64'>: <function <lambda> at 0x132ba28>, <type 'numpy.object_'>: <function <lambda> at 0x132baa0>, <type 'numpy.float64'>: <function <lambda> at 0x132bb18>, <type 'numpy.int64'>: <function <lambda> at 0x132bb90>, <type 'numpy.uint8'>: <function <lambda> at 0x132bc08>, <type 'numpy.datetime64'>: <function <lambda> at 0x132bc80>, <type 'numpy.complex256'>: <function <lambda> at 0x132bcf8>, <type 'numpy.float32'>: <function <lambda> at 0x132bd70>, <type 'numpy.uint32'>: <function <lambda> at 0x132bde8>, <type 'numpy.int8'>: <function <lambda> at 0x132be60>, <type 'numpy.void'>: <function <lambda> at 0x132bed8>, <type 'numpy.complex128'>: <function <lambda> at 0x132bf50>, <type 'numpy.uint64'>: <function <lambda> at 0x132d050>, <type 'numpy.int32'>: <function <lambda> at 0x132d0c8>, <type 'numpy.bool_'>: <function <lambda> at 0x132d140>, <type 'numpy.unicode_'>: <function <lambda> at 0x132d1b8>, <type 'numpy.complex64'>: <function <lambda> at 0x132d230>, <type 'numpy.int64'>: <function <lambda> at 0x132d2a8>, <type 'numpy.uint16'>: <function <lambda> at 0x132d320>}
#
# Nome do objeto: cbook
# Identificador: 28503912
# Tipo: <type 'module'>
# Representação: <module 'matplotlib.cbook' from '/usr/lib/pymodules/python2.7/matplotlib/cbook.pyc'>
# itens:
# Bunch
# CallbackRegistry
# GetRealpathAndStat
# Grouper
# Idle
# MemoryMonitor
# Null
# RingBuffer
# Scheduler
# Sorter
# Stack
# Timeout
# WeakKeyDictionary
# Xlator
# _BoundMethodProxy
# _InstanceMethodPickler
# _NestedClassGetter
# __builtins__
# __doc__
# __file__
# __name__
# __package__
# _check_output
# _dedent_regex
# _find_dedent_regex
# _linestyles
# _putmask
# _safezip_msg
# align_iterators
# allequal
# allpairs
# alltrue
# check_output
# converter
# datetime
# dedent
# delete_masked_points
# dict_delall
# distances_along_curve
# errno
# exception_to_str
# finddir
# flatten
# get_realpath_and_stat
# get_recursive_filelist
# get_sample_data
# get_split_ind
# glob
# gzip
# io
# is_closed_polygon
# is_math_text
# is_numlike
# is_scalar
# is_scalar_or_string
# is_sequence_of_strings
# is_string_like
# is_writable_file_like
# issubclass_safe
# iterable
# less_simple_linear_interpolation
# listFiles
# locale
# ls
# ls_mapper
# ma
# matplotlib
# maxdict
# mkdirs
# mplDeprecation
# new
# np
# onetrue
# os
# path_length
# pieces
# popall
# print_cycles
# print_function
# quad2cubic
# re
# recursive_remove
# reduce
# ref
# report_memory
# restrict_dict
# reverse_dict
# safe_masked_invalid
# safezip
# silent_list
# simple_linear_interpolation
# soundex
# strip_math
# subprocess
# sys
# threading
# time
# to_filehandle
# todate
# todatetime
# tofloat
# toint
# tostr
# traceback
# unicode_safe
# unique
# unmasked_index_ranges
# vector_lengths
# warnings
# wrap
#
# Nome do objeto: cdouble
# Identificador: 139890523401664
# Tipo: <type 'type'>
# Representação: <type 'numpy.complex128'>
#
# Nome do objeto: ceil
# Identificador: 19540416
# Tipo: <type 'numpy.ufunc'>
# Representação: <ufunc 'ceil'>
#
# Nome do objeto: center_matrix
# Identificador: 32387752
# Tipo: <type 'function'>
# Representação: <function center_matrix at 0x1ee32a8>
#
# Nome do objeto: cfloat
# Identificador: 139890523401664
# Tipo: <type 'type'>
# Representação: <type 'numpy.complex128'>
#
# Nome do objeto: char
# Identificador: 20804336
# Tipo: <type 'module'>
# Representação: <module 'numpy.core.defchararray' from '/usr/lib/python2.7/dist-packages/numpy/core/defchararray.pyc'>
# itens:
# __all__
# __builtins__
# __doc__
# __file__
# __name__
# __package__
# _bytes
# _clean_args
# _get_num_chars
# _globalvar
# _len
# _to_string_or_unicode_array
# _unicode
# _use_unicode
# _vec_string
# add
# array
# asarray
# asbytes
# bool_
# capitalize
# center
# character
# chararray
# compare_chararrays
# count
# decode
# encode
# endswith
# equal
# expandtabs
# find
# greater
# greater_equal
# index
# integer
# isalnum
# isalpha
# isdecimal
# isdigit
# islower
# isnumeric
# isspace
# istitle
# isupper
# join
# less
# less_equal
# ljust
# lower
# lstrip
# mod
# multiply
# narray
# ndarray
# not_equal
# numpy
# object_
# partition
# replace
# rfind
# rindex
# rjust
# rpartition
# rsplit
# rstrip
# split
# splitlines
# startswith
# str_len
# string_
# strip
# swapcase
# sys
# title
# translate
# unicode_
# upper
# zfill
#
# Nome do objeto: character
# Identificador: 139890523413792
# Tipo: <type 'type'>
# Representação: <type 'numpy.character'>
#
# Nome do objeto: chararray
# Identificador: 21117840
# Tipo: <type 'type'>
# Representação: <class 'numpy.core.defchararray.chararray'>
#
# Nome do objeto: chisquare
# Identificador: 23954064
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in method chisquare of mtrand.RandomState object at 0x7f3ad35f43d8>
#
# Nome do objeto: cholesky
# Identificador: 21912704
# Tipo: <type 'function'>
# Representação: <function cholesky at 0x14e5c80>
#
# Nome do objeto: choose
# Identificador: 20151664
# Tipo: <type 'function'>
# Representação: <function choose at 0x1337d70>
#
# Nome do objeto: cla
# Identificador: 36953576
# Tipo: <type 'function'>
# Representação: <function cla at 0x233dde8>
#
# Nome do objeto: clabel
# Identificador: 36949000
# Tipo: <type 'function'>
# Representação: <function clabel at 0x233cc08>
#
# Nome do objeto: clf
# Identificador: 36899848
# Tipo: <type 'function'>
# Representação: <function clf at 0x2330c08>
#
# Nome do objeto: clim
# Identificador: 36946480
# Tipo: <type 'function'>
# Representação: <function clim at 0x233c230>
#
# Nome do objeto: clip
# Identificador: 20731496
# Tipo: <type 'function'>
# Representação: <function clip at 0x13c5668>
#
# Nome do objeto: clongdouble
# Identificador: 139890523401248
# Tipo: <type 'type'>
# Representação: <type 'numpy.complex256'>
#
# Nome do objeto: clongfloat
# Identificador: 139890523401248
# Tipo: <type 'type'>
# Representação: <type 'numpy.complex256'>
#
# Nome do objeto: close
# Identificador: 36899488
# Tipo: <type 'function'>
# Representação: <function close at 0x2330aa0>
#
# Nome do objeto: cm
# Identificador: 33704488
# Tipo: <type 'module'>
# Representação: <module 'matplotlib.cm' from '/usr/lib/pymodules/python2.7/matplotlib/cm.pyc'>
# itens:
# Accent
# Accent_r
# Blues
# Blues_r
# BrBG
# BrBG_r
# BuGn
# BuGn_r
# BuPu
# BuPu_r
# CMRmap
# CMRmap_r
# Dark2
# Dark2_r
# GnBu
# GnBu_r
# Greens
# Greens_r
# Greys
# Greys_r
# LUTSIZE
# OrRd
# OrRd_r
# Oranges
# Oranges_r
# PRGn
# PRGn_r
# Paired
# Paired_r
# Pastel1
# Pastel1_r
# Pastel2
# Pastel2_r
# PiYG
# PiYG_r
# PuBu
# PuBuGn
# PuBuGn_r
# PuBu_r
# PuOr
# PuOr_r
# PuRd
# PuRd_r
# Purples
# Purples_r
# RdBu
# RdBu_r
# RdGy
# RdGy_r
# RdPu
# RdPu_r
# RdYlBu
# RdYlBu_r
# RdYlGn
# RdYlGn_r
# Reds
# Reds_r
# ScalarMappable
# Set1
# Set1_r
# Set2
# Set2_r
# Set3
# Set3_r
# Spectral
# Spectral_r
# YlGn
# YlGnBu
# YlGnBu_r
# YlGn_r
# YlOrBr
# YlOrBr_r
# YlOrRd
# YlOrRd_r
# __builtins__
# __doc__
# __file__
# __name__
# __package__
# _cmapnames
# _generate_cmap
# _reverse_cmap_spec
# _reverser
# afmhot
# afmhot_r
# autumn
# autumn_r
# binary
# binary_r
# bone
# bone_r
# brg
# brg_r
# bwr
# bwr_r
# cbook
# cmap_d
# cmapname
# colors
# cool
# cool_r
# coolwarm
# coolwarm_r
# copper
# copper_r
# cubehelix
# cubehelix_r
# datad
# division
# flag
# flag_r
# get_cmap
# gist_earth
# gist_earth_r
# gist_gray
# gist_gray_r
# gist_heat
# gist_heat_r
# gist_ncar
# gist_ncar_r
# gist_rainbow
# gist_rainbow_r
# gist_stern
# gist_stern_r
# gist_yarg
# gist_yarg_r
# gnuplot
# gnuplot2
# gnuplot2_r
# gnuplot_r
# gray
# gray_r
# hot
# hot_r
# hsv
# hsv_r
# jet
# jet_r
# ma
# mpl
# np
# ocean
# ocean_r
# os
# pink
# pink_r
# print_function
# prism
# prism_r
# rainbow
# rainbow_r
# register_cmap
# revcmap
# seismic
# seismic_r
# spec
# spec_reversed
# spectral
# spectral_r
# spring
# spring_r
# summer
# summer_r
# terrain
# terrain_r
# winter
# winter_r
#
# Nome do objeto: cohere
# Identificador: 36948880
# Tipo: <type 'function'>
# Representação: <function cohere at 0x233cb90>
#
# Nome do objeto: colorbar
# Identificador: 36946360
# Tipo: <type 'function'>
# Representação: <function colorbar at 0x233c1b8>
#
# Nome do objeto: colormaps
# Identificador: 36946120
# Tipo: <type 'function'>
# Representação: <function colormaps at 0x233c0c8>
#
# Nome do objeto: colors
# Identificador: 36946000
# Tipo: <type 'function'>
# Representação: <function colors at 0x233c050>
#
# Nome do objeto: column_stack
# Identificador: 21901992
# Tipo: <type 'function'>
# Representação: <function column_stack at 0x14e32a8>
#
# Nome do objeto: common_type
# Identificador: 21508656
# Tipo: <type 'function'>
# Representação: <function common_type at 0x1483230>
#
# Nome do objeto: compare_chararrays
# Identificador: 19378544
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in function compare_chararrays>
#
# Nome do objeto: complex128
# Identificador: 139890523401664
# Tipo: <type 'type'>
# Representação: <type 'numpy.complex128'>
#
# Nome do objeto: complex256
# Identificador: 139890523401248
# Tipo: <type 'type'>
# Representação: <type 'numpy.complex256'>
#
# Nome do objeto: complex64
# Identificador: 139890523402080
# Tipo: <type 'type'>
# Representação: <type 'numpy.complex64'>
#
# Nome do objeto: complex_
# Identificador: 139890523401664
# Tipo: <type 'type'>
# Representação: <type 'numpy.complex128'>
#
# Nome do objeto: complexfloating
# Identificador: 139890523412960
# Tipo: <type 'type'>
# Representação: <type 'numpy.complexfloating'>
#
# Nome do objeto: compress
# Identificador: 20731376
# Tipo: <type 'function'>
# Representação: <function compress at 0x13c55f0>
#
# Nome do objeto: concatenate
# Identificador: 19352320
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in function concatenate>
#
# Nome do objeto: cond
# Identificador: 22360264
# Tipo: <type 'function'>
# Representação: <function cond at 0x15530c8>
#
# Nome do objeto: conj
# Identificador: 17742704
# Tipo: <type 'numpy.ufunc'>
# Representação: <ufunc 'conjugate'>
#
# Nome do objeto: conjugate
# Identificador: 17742704
# Tipo: <type 'numpy.ufunc'>
# Representação: <ufunc 'conjugate'>
#
# Nome do objeto: connect
# Identificador: 36899608
# Tipo: <type 'function'>
# Representação: <function connect at 0x2330b18>
#
# Nome do objeto: contour
# Identificador: 36949120
# Tipo: <type 'function'>
# Representação: <function contour at 0x233cc80>
#
# Nome do objeto: contourf
# Identificador: 36949240
# Tipo: <type 'function'>
# Representação: <function contourf at 0x233ccf8>
#
# Nome do objeto: convolve
# Identificador: 20148304
# Tipo: <type 'function'>
# Representação: <function convolve at 0x1337050>
#
# Nome do objeto: cool
# Identificador: 36955152
# Tipo: <type 'function'>
# Representação: <function cool at 0x233e410>
#
# Nome do objeto: copper
# Identificador: 36955272
# Tipo: <type 'function'>
# Representação: <function copper at 0x233e488>
#
# Nome do objeto: copy
# Identificador: 21855000
# Tipo: <type 'function'>
# Representação: <function copy at 0x14d7b18>
#
# Nome do objeto: copysign
# Identificador: 17884688
# Tipo: <type 'numpy.ufunc'>
# Representação: <ufunc 'copysign'>
#
# Nome do objeto: copyto
# Identificador: 19351384
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in function copyto>
#
# Nome do objeto: corrcoef
# Identificador: 21862112
# Tipo: <type 'function'>
# Representação: <function corrcoef at 0x14d96e0>
#
# Nome do objeto: correlate
# Identificador: 20111184
# Tipo: <type 'function'>
# Representação: <function correlate at 0x132df50>
#
# Nome do objeto: cos
# Identificador: 18251808
# Tipo: <type 'numpy.ufunc'>
# Representação: <ufunc 'cos'>
#
# Nome do objeto: cosh
# Identificador: 17888192
# Tipo: <type 'numpy.ufunc'>
# Representação: <ufunc 'cosh'>
#
# Nome do objeto: count_nonzero
# Identificador: 19351672
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in function count_nonzero>
#
# Nome do objeto: cov
# Identificador: 21861512
# Tipo: <type 'function'>
# Representação: <function cov at 0x14d9488>
#
# Nome do objeto: cross
# Identificador: 20149024
# Tipo: <type 'function'>
# Representação: <function cross at 0x1337320>
#
# Nome do objeto: csd
# Identificador: 36949360
# Tipo: <type 'function'>
# Representação: <function csd at 0x233cd70>
#
# Nome do objeto: csingle
# Identificador: 139890523402080
# Tipo: <type 'type'>
# Representação: <type 'numpy.complex64'>
#
# Nome do objeto: csv2rec
# Identificador: 32392808
# Tipo: <type 'function'>
# Representação: <function csv2rec at 0x1ee4668>
#
# Nome do objeto: ctypeslib
# Identificador: 23911680
# Tipo: <type 'module'>
# Representação: <module 'numpy.ctypeslib' from '/usr/lib/python2.7/dist-packages/numpy/ctypeslib.pyc'>
# itens:
# _ARRAY_TYPE
# __all__
# __builtins__
# __doc__
# __file__
# __name__
# __package__
# _dtype
# _flagdict
# _flagnames
# _flags_fromnum
# _ndptr
# _ndptr_base
# _num_fromflags
# ...
#
# Nome do objeto: triangular
# Identificador: 23955072
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in method triangular of mtrand.RandomState object at 0x7f3ad35f43d8>
#
# Nome do objeto: tricontour
# Identificador: 36952736
# Tipo: <type 'function'>
# Representação: <function tricontour at 0x233daa0>
#
# Nome do objeto: tricontourf
# Identificador: 36952856
# Tipo: <type 'function'>
# Representação: <function tricontourf at 0x233db18>
#
# Nome do objeto: tril
# Identificador: 21511776
# Tipo: <type 'function'>
# Representação: <function tril at 0x1483e60>
#
# Nome do objeto: tril_indices
# Identificador: 21803328
# Tipo: <type 'function'>
# Representação: <function tril_indices at 0x14cb140>
#
# Nome do objeto: tril_indices_from
# Identificador: 21803448
# Tipo: <type 'function'>
# Representação: <function tril_indices_from at 0x14cb1b8>
#
# Nome do objeto: trim_zeros
# Identificador: 21855840
# Tipo: <type 'function'>
# Representação: <function trim_zeros at 0x14d7e60>
#
# Nome do objeto: tripcolor
# Identificador: 36952976
# Tipo: <type 'function'>
# Representação: <function tripcolor at 0x233db90>
#
# Nome do objeto: triplot
# Identificador: 36953096
# Tipo: <type 'function'>
# Representação: <function triplot at 0x233dc08>
#
# Nome do objeto: triu
# Identificador: 21511896
# Tipo: <type 'function'>
# Representação: <function triu at 0x1483ed8>
#
# Nome do objeto: triu_indices
# Identificador: 21803568
# Tipo: <type 'function'>
# Representação: <function triu_indices at 0x14cb230>
#
# Nome do objeto: triu_indices_from
# Identificador: 21803688
# Tipo: <type 'function'>
# Representação: <function triu_indices_from at 0x14cb2a8>
#
# Nome do objeto: true_divide
# Identificador: 18165600
# Tipo: <type 'numpy.ufunc'>
# Representação: <ufunc 'true_divide'>
#
# Nome do objeto: trunc
# Identificador: 18074560
# Tipo: <type 'numpy.ufunc'>
# Representação: <ufunc 'trunc'>
#
# Nome do objeto: twinx
# Identificador: 36943224
# Tipo: <type 'function'>
# Representação: <function twinx at 0x233b578>
#
# Nome do objeto: twiny
# Identificador: 36943344
# Tipo: <type 'function'>
# Representação: <function twiny at 0x233b5f0>
#
# Nome do objeto: typeDict
# Identificador: 20317856
# Tipo: <type 'dict'>
# Representação: {0: <type 'numpy.bool_'>, 1: <type 'numpy.int8'>, 2: <type 'numpy.uint8'>, 3: <type 'numpy.int16'>, 4: <type 'numpy.uint16'>, 5: <type 'numpy.int32'>, 6: <type 'numpy.uint32'>, 7: <type 'numpy.int64'>, 8: <type 'numpy.uint64'>, 9: <type 'numpy.int64'>, 10: <type 'numpy.uint64'>, 11: <type 'numpy.float32'>, 12: <type 'numpy.float64'>, 13: <type 'numpy.float128'>, 14: <type 'numpy.complex64'>, 15: <type 'numpy.complex128'>, 16: <type 'numpy.complex256'>, 17: <type 'numpy.object_'>, 18: <type 'numpy.string_'>, 19: <type 'numpy.unicode_'>, 20: <type 'numpy.void'>, 21: <type 'numpy.datetime64'>, 'unicode': <type 'numpy.unicode_'>, 23: <type 'numpy.float16'>, 'cfloat': <type 'numpy.complex128'>, 'longfloat': <type 'numpy.float128'>, 'Int32': <type 'numpy.int32'>, 'Complex64': <type 'numpy.complex128'>, 'unicode_': <type 'numpy.unicode_'>, 'complex': <type 'numpy.complex128'>, 'timedelta64': <type 'numpy.timedelta64'>, 'uint16': <type 'numpy.uint16'>, 'c16': <type 'numpy.complex128'>, 'float32': <type 'numpy.float32'>, 'complex256': <type 'numpy.complex256'>, 'D': <type 'numpy.complex128'>, 'H': <type 'numpy.uint16'>, 'void': <type 'numpy.void'>, 'unicode0': <type 'numpy.unicode_'>, 'L': <type 'numpy.uint64'>, 'P': <type 'numpy.uint64'>, 'half': <type 'numpy.float16'>, 'void0': <type 'numpy.void'>, 'd': <type 'numpy.float64'>, 'h': <type 'numpy.int16'>, 'l': <type 'numpy.int64'>, 'p': <type 'numpy.int64'>, 'c32': <type 'numpy.complex256'>, 22: <type 'numpy.timedelta64'>, 'O8': <type 'numpy.object_'>, 'Timedelta64': <type 'numpy.timedelta64'>, 'object0': <type 'numpy.object_'>, 'b1': <type 'numpy.bool_'>, 'float128': <type 'numpy.float128'>, 'M8': <type 'numpy.datetime64'>, 'String0': <type 'numpy.string_'>, 'float16': <type 'numpy.float16'>, 'ulonglong': <type 'numpy.uint64'>, 'i1': <type 'numpy.int8'>, 'uint32': <type 'numpy.uint32'>, '?': <type 'numpy.bool_'>, 'Void0': <type 'numpy.void'>, 'complex64': <type 'numpy.complex64'>, 'G': <type 'numpy.complex256'>, 'O': <type 'numpy.object_'>, 'UInt8': <type 'numpy.uint8'>, 'S': <type 'numpy.string_'>, 'byte': <type 'numpy.int8'>, 'UInt64': <type 'numpy.uint64'>, 'g': <type 'numpy.float128'>, 'float64': <type 'numpy.float64'>, 'ushort': <type 'numpy.uint16'>, 'float_': <type 'numpy.float64'>, 'uint': <type 'numpy.uint64'>, 'object_': <type 'numpy.object_'>, 'Float16': <type 'numpy.float16'>, 'complex_': <type 'numpy.complex128'>, 'Unicode0': <type 'numpy.unicode_'>, 'uintp': <type 'numpy.uint64'>, 'intc': <type 'numpy.int32'>, 'csingle': <type 'numpy.complex64'>, 'datetime64': <type 'numpy.datetime64'>, 'float': <type 'numpy.float64'>, 'bool8': <type 'numpy.bool_'>, 'Bool': <type 'numpy.bool_'>, 'intp': <type 'numpy.int64'>, 'uintc': <type 'numpy.uint32'>, 'bytes_': <type 'numpy.string_'>, 'u8': <type 'numpy.uint64'>, 'u4': <type 'numpy.uint32'>, 'int_': <type 'numpy.int64'>, 'cdouble': <type 'numpy.complex128'>, 'u1': <type 'numpy.uint8'>, 'complex128': <type 'numpy.complex128'>, 'u2': <type 'numpy.uint16'>, 'f8': <type 'numpy.float64'>, 'Datetime64': <type 'numpy.datetime64'>, 'ubyte': <type 'numpy.uint8'>, 'm8': <type 'numpy.timedelta64'>, 'B': <type 'numpy.uint8'>, 'uint0': <type 'numpy.uint64'>, 'F': <type 'numpy.complex64'>, 'bool_': <type 'numpy.bool_'>, 'uint8': <type 'numpy.uint8'>, 'c8': <type 'numpy.complex64'>, 'Int64': <type 'numpy.int64'>, 'Int8': <type 'numpy.int8'>, 'Complex32': <type 'numpy.complex64'>, 'V': <type 'numpy.void'>, 'int8': <type 'numpy.int8'>, 'uint64': <type 'numpy.uint64'>, 'b': <type 'numpy.int8'>, 'f': <type 'numpy.float32'>, 'double': <type 'numpy.float64'>, 'UInt32': <type 'numpy.uint32'>, 'clongdouble': <type 'numpy.complex256'>, 'str': <type 'numpy.string_'>, 'f16': <type 'numpy.float128'>, 'f2': <type 'numpy.float16'>, 'f4': <type 'numpy.float32'>, 'int32': <type 'numpy.int32'>, 'int': <type 'numpy.int64'>, 'longdouble': <type 'numpy.float128'>, 'Complex128': <type 'numpy.complex256'>, 'single': <type 'numpy.float32'>, 'string': <typ ...
#
# Nome do objeto: typeNA
# Identificador: 20318144
# Tipo: <type 'dict'>
# Representação: {<type 'numpy.float16'>: 'Float16', <type 'numpy.int16'>: 'Int16', 'Int32': <type 'numpy.int32'>, 'Complex64': <type 'numpy.complex128'>, <type 'numpy.timedelta64'>: 'Timedelta64', <type 'numpy.uint8'>: 'UInt8', 'c16': 'Complex64', <type 'numpy.datetime64'>: 'Datetime64', 'D': 'Complex64', <type 'numpy.int8'>: 'Int8', 'H': 'UInt16', 'L': 'UInt64', <type 'numpy.void'>: 'Void0', <type 'numpy.bool_'>: 'Bool', 'd': 'Float64', 'h': 'Int16', 'l': 'Int64', <type 'numpy.unicode_'>: 'Unicode0', 'c32': 'Complex128', <type 'numpy.string_'>: 'String0', 'b1': 'Bool', 'M8': 'Datetime64', 'String0': <type 'numpy.string_'>, <type 'numpy.object_'>: 'Object0', 'I': 'UInt32', '?': 'Bool', 'Void0': <type 'numpy.void'>, <type 'numpy.complex256'>: 'Complex128', 'G': 'Complex128', 'O': 'Object0', 'UInt8': <type 'numpy.uint8'>, 'S': 'String0', <type 'numpy.complex128'>: 'Complex64', 'UInt64': <type 'numpy.uint64'>, 'g': 'Float128', <type 'numpy.complex64'>: 'Complex32', 'Float16': <type 'numpy.float16'>, <type 'numpy.float128'>: 'Float128', 'Bool': <type 'numpy.bool_'>, 'u8': <type 'numpy.uint64'>, 'u4': <type 'numpy.uint32'>, <type 'numpy.float64'>: 'Float64', 'Unicode0': <type 'numpy.unicode_'>, 'u1': <type 'numpy.uint8'>, 'u2': <type 'numpy.uint16'>, 'Datetime64': <type 'numpy.datetime64'>, 'Int8': <type 'numpy.int8'>, 'B': 'UInt8', <type 'numpy.float32'>: 'Float32', 'F': 'Complex32', 'c8': 'Complex32', 'Int64': <type 'numpy.int64'>, 'Timedelta64': <type 'numpy.timedelta64'>, 'Complex32': <type 'numpy.complex64'>, 'V': 'Void0', <type 'numpy.uint64'>: 'UInt64', 'b': 'Int8', 'f': 'Float32', 'm8': 'Timedelta64', <type 'numpy.int64'>: 'Int64', 'f16': 'Float128', 'UInt32': <type 'numpy.uint32'>, 'f2': 'Float16', 'f4': 'Float32', 'f8': 'Float64', 'Complex128': <type 'numpy.complex256'>, <type 'numpy.uint64'>: 'UInt64', 'Object0': <type 'numpy.object_'>, 'Int16': <type 'numpy.int16'>, 'Float64': <type 'numpy.float64'>, <type 'numpy.int64'>: 'Int64', 'UInt16': <type 'numpy.uint16'>, 'Float32': <type 'numpy.float32'>, 'i8': <type 'numpy.int64'>, <type 'numpy.uint32'>: 'UInt32', 'i1': <type 'numpy.int8'>, 'i2': <type 'numpy.int16'>, 'M': 'Datetime64', 'i4': <type 'numpy.int32'>, 'Q': 'UInt64', 'U': 'Unicode0', <type 'numpy.int32'>: 'Int32', 'e': 'Float16', 'i': 'Int32', 'm': 'Timedelta64', 'q': 'Int64', 'Float128': <type 'numpy.float128'>, <type 'numpy.uint16'>: 'UInt16'}
#
# Nome do objeto: typecodes
# Identificador: 20326608
# Tipo: <type 'dict'>
# Representação: {'All': '?bhilqpBHILQPefdgFDGSUVOMm', 'Complex': 'FDG', 'AllFloat': 'efdgFDG', 'Integer': 'bhilqp', 'UnsignedInteger': 'BHILQP', 'Float': 'efdg', 'Character': 'c', 'Datetime': 'Mm', 'AllInteger': 'bBhHiIlLqQpP'}
#
# Nome do objeto: typename
# Identificador: 21508536
# Tipo: <type 'function'>
# Representação: <function typename at 0x14831b8>
#
# Nome do objeto: ubyte
# Identificador: 139890523407072
# Tipo: <type 'type'>
# Representação: <type 'numpy.uint8'>
#
# Nome do objeto: ufunc
# Identificador: 139890520077536
# Tipo: <type 'type'>
# Representação: <type 'numpy.ufunc'>
#
# Nome do objeto: uint
# Identificador: 139890523404576
# Tipo: <type 'type'>
# Representação: <type 'numpy.uint64'>
#
# Nome do objeto: uint0
# Identificador: 139890523404576
# Tipo: <type 'type'>
# Representação: <type 'numpy.uint64'>
#
# Nome do objeto: uint16
# Identificador: 139890523406240
# Tipo: <type 'type'>
# Representação: <type 'numpy.uint16'>
#
# Nome do objeto: uint32
# Identificador: 139890523405408
# Tipo: <type 'type'>
# Representação: <type 'numpy.uint32'>
#
# Nome do objeto: uint64
# Identificador: 139890523404576
# Tipo: <type 'type'>
# Representação: <type 'numpy.uint64'>
#
# Nome do objeto: uint8
# Identificador: 139890523407072
# Tipo: <type 'type'>
# Representação: <type 'numpy.uint8'>
#
# Nome do objeto: uintc
# Identificador: 139890523405408
# Tipo: <type 'type'>
# Representação: <type 'numpy.uint32'>
#
# Nome do objeto: uintp
# Identificador: 139890523404576
# Tipo: <type 'type'>
# Representação: <type 'numpy.uint64'>
#
# Nome do objeto: ulonglong
# Identificador: 139890523403744
# Tipo: <type 'type'>
# Representação: <type 'numpy.uint64'>
#
# Nome do objeto: unicode0
# Identificador: 139890523400000
# Tipo: <type 'type'>
# Representação: <type 'numpy.unicode_'>
#
# Nome do objeto: unicode_
# Identificador: 139890523400000
# Tipo: <type 'type'>
# Representação: <type 'numpy.unicode_'>
#
# Nome do objeto: uniform
# Identificador: 23920296
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in method uniform of mtrand.RandomState object at 0x7f3ad35f43d8>
#
# Nome do objeto: union1d
# Identificador: 21853920
# Tipo: <type 'function'>
# Representação: <function union1d at 0x14d76e0>
#
# Nome do objeto: unique
# Identificador: 21853440
# Tipo: <type 'function'>
# Representação: <function unique at 0x14d7500>
#
# Nome do objeto: unpackbits
# Identificador: 21780168
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in function unpackbits>
#
# Nome do objeto: unravel_index
# Identificador: 21779880
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in function unravel_index>
#
# Nome do objeto: unsignedinteger
# Identificador: 139890523411712
# Tipo: <type 'type'>
# Representação: <type 'numpy.unsignedinteger'>
#
# Nome do objeto: unwrap
# Identificador: 21855600
# Tipo: <type 'function'>
# Representação: <function unwrap at 0x14d7d70>
#
# Nome do objeto: ushort
# Identificador: 139890523406240
# Tipo: <type 'type'>
# Representação: <type 'numpy.uint16'>
#
# Nome do objeto: vander
# Identificador: 21512016
# Tipo: <type 'function'>
# Representação: <function vander at 0x1483f50>
#
# Nome do objeto: var
# Identificador: 20734272
# Tipo: <type 'function'>
# Representação: <function var at 0x13c6140>
#
# Nome do objeto: vdot
# Identificador: 20024640
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in function vdot>
#
# Nome do objeto: vector_lengths
# Identificador: 32397864
# Tipo: <type 'function'>
# Representação: <function vector_lengths at 0x1ee5a28>
#
# Nome do objeto: vectorize
# Identificador: 22002672
# Tipo: <type 'type'>
# Representação: <class 'numpy.lib.function_base.vectorize'>
#
# Nome do objeto: vlines
# Identificador: 36953216
# Tipo: <type 'function'>
# Representação: <function vlines at 0x233dc80>
#
# Nome do objeto: void
# Identificador: 139890523399584
# Tipo: <type 'type'>
# Representação: <type 'numpy.void'>
#
# Nome do objeto: void0
# Identificador: 139890523399584
# Tipo: <type 'type'>
# Representação: <type 'numpy.void'>
#
# Nome do objeto: vonmises
# Identificador: 23954352
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in method vonmises of mtrand.RandomState object at 0x7f3ad35f43d8>
#
# Nome do objeto: vsplit
# Identificador: 21902712
# Tipo: <type 'function'>
# Representação: <function vsplit at 0x14e3578>
#
# Nome do objeto: vstack
# Identificador: 20856056
# Tipo: <type 'function'>
# Representação: <function vstack at 0x13e3cf8>
#
# Nome do objeto: waitforbuttonpress
# Identificador: 36900448
# Tipo: <type 'function'>
# Representação: <function waitforbuttonpress at 0x2330e60>
#
# Nome do objeto: wald
# Identificador: 23955000
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in method wald of mtrand.RandomState object at 0x7f3ad35f43d8>
#
# Nome do objeto: warnings
# Identificador: 139890631215600
# Tipo: <type 'module'>
# Representação: <module 'warnings' from '/usr/lib/python2.7/warnings.pyc'>
# itens:
# WarningMessage
# _OptionError
# __all__
# __builtins__
# __doc__
# __file__
# __name__
# __package__
# _getaction
# _getcategory
# _processoptions
# _setoption
# _show_warning
# catch_warnings
# default_action
# defaultaction
# filters
# filterwarnings
# formatwarning
# linecache
# once_registry
# onceregistry
# resetwarnings
# showwarning
# simplefilter
# sys
# types
# warn
# warn_explicit
# warnpy3k
#
# Nome do objeto: weibull
# Identificador: 23954496
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in method weibull of mtrand.RandomState object at 0x7f3ad35f43d8>
#
# Nome do objeto: where
# Identificador: 19351960
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in function where>
#
# Nome do objeto: who
# Identificador: 21805968
# Tipo: <type 'function'>
# Representação: <function who at 0x14cbb90>
#
# Nome do objeto: window_hanning
# Identificador: 32383776
# Tipo: <type 'function'>
# Representação: <function window_hanning at 0x1ee2320>
#
# Nome do objeto: window_none
# Identificador: 32383896
# Tipo: <type 'function'>
# Representação: <function window_none at 0x1ee2398>
#
# Nome do objeto: winter
# Identificador: 36956472
# Tipo: <type 'function'>
# Representação: <function winter at 0x233e938>
#
# Nome do objeto: xcorr
# Identificador: 36953336
# Tipo: <type 'function'>
# Representação: <function xcorr at 0x233dcf8>
#
# Nome do objeto: xlabel
# Identificador: 36944184
# Tipo: <type 'function'>
# Representação: <function xlabel at 0x233b938>
#
# Nome do objeto: xlim
# Identificador: 36944424
# Tipo: <type 'function'>
# Representação: <function xlim at 0x233ba28>
#
# Nome do objeto: xscale
# Identificador: 36944664
# Tipo: <type 'function'>
# Representação: <function xscale at 0x233bb18>
#
# Nome do objeto: xticks
# Identificador: 36944904
# Tipo: <type 'function'>
# Representação: <function xticks at 0x233bc08>
#
# Nome do objeto: ylabel
# Identificador: 36944304
# Tipo: <type 'function'>
# Representação: <function ylabel at 0x233b9b0>
#
# Nome do objeto: ylim
# Identificador: 36944544
# Tipo: <type 'function'>
# Representação: <function ylim at 0x233baa0>
#
# Nome do objeto: yscale
# Identificador: 36944784
# Tipo: <type 'function'>
# Representação: <function yscale at 0x233bb90>
#
# Nome do objeto: yticks
# Identificador: 36945024
# Tipo: <type 'function'>
# Representação: <function yticks at 0x233bc80>
#
# Nome do objeto: zeros
# Identificador: 19351600
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in function zeros>
#
# Nome do objeto: zeros_like
# Identificador: 20109624
# Tipo: <type 'function'>
# Representação: <function zeros_like at 0x132d938>
#
# Nome do objeto: zipf
# Identificador: 23955360
# Tipo: <type 'builtin_function_or_method'>
# Representação: <built-in method zipf of mtrand.RandomState object at 0x7f3ad35f43d8>

# %% [markdown]
# O Python também tem um módulo chamado *types*, que tem as definições dos tipos básicos do interpretador.
#
# Exemplo:

# %%
import types

s = ''
if isinstance(s, types.StringType):
    print 's é uma string.'
# Out:
# s é uma string.

# %% [markdown]
# Através da introspecção, é possível determinar os campos de uma tabela de banco de dados, por exemplo.
#
# Inspect
# -------
# O módulo *inspect* provê um conjunto de funções de alto nível para introspecção que permitem investigar tipos , itens de coleções, classes, funções, código fonte e a pilha de execução do interpretador.
#
# Exemplo:

# %%
import os.path
# inspect: módulo de introspecção "amigável"
import inspect

print 'Objeto:', inspect.getmodule(os.path)

print 'Classe?', inspect.isclass(str)

# Lista todas as funções que existem em "os.path"

print 'Membros:',

for name, struct in inspect.getmembers(os.path):

    if inspect.isfunction(struct):
        print name,
# Out:
# Objeto: <module 'posixpath' from '/usr/lib/python2.7/posixpath.pyc'>
# Classe? True
# Membros: _joinrealpath abspath basename commonprefix dirname exists expanduser expandvars getatime getctime getmtime getsize isabs isdir isfile islink ismount join lexists normcase normpath realpath relpath samefile sameopenfile samestat split splitdrive splitext walk

# %% [markdown]
# As funções que trabalham com a pilha do interpretador devem ser usadas com cuidado, pois é possível criar referências cíclicas (uma variável que aponta para o item da pilha que tem a própria variável). A existência de referências a itens da pilha retarda a destruição dos itens pelo coletor de lixo do interpretador.

# %%
# Out:
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-left:16% !important;
#         margin-right:auto;
#     }
#     h1 {
#         font-family: Helvetica, serif;
#     }
#     h4{
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 130%;
#         width:800px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
#     .note{
#             border-bottom: 1px black dotted;
#     }
#     .prompt{
#         display: None;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 16pt;
#         color: #4057A1;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
#      table {
#         width: 100%;
#         margin: 0 !important;
#         }
#      table th, table td {
#         text-align: center !important;
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>
